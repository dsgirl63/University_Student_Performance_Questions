# %% [markdown]
# #KHUSHI SHARMA

# %%
import seaborn as sb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("University_Student_Performance.csv")

# %%
df
# Out:
#      StudentID         Name  Course  Year  MathScore  ScienceScore  \
# 0      STU1000    Student_0    B.Sc     4         26            67
# 1      STU1001    Student_1  B.Tech     3         93            63
# 2      STU1002    Student_2   B.Com     2         84            93
# 3      STU1003    Student_3    B.Sc     4         43            18
# 4      STU1004    Student_4   B.Com     4         34            86
# ...        ...          ...     ...   ...        ...           ...
# 1015   STU1650  Student_650      BA     2         65            71
# 1016   STU1907  Student_907   B.Com     3         64            85
# 1017   STU1660  Student_660      BA     4          0            96
# 1018   STU1231  Student_231    B.Sc     4         47            18
# 1019   STU1048   Student_48   B.Com     3         26            51
#
#       EnglishScore  Attendance
# 0               48       93.32
# 1                0       59.56
# 2               21       48.01
# 3               92       69.36
# ...

# %%
#top five values of dataset
df.head()
# Out:
#   StudentID       Name  Course  Year  MathScore  ScienceScore  EnglishScore  \
# 0   STU1000  Student_0    B.Sc     4         26            67            48
# 1   STU1001  Student_1  B.Tech     3         93            63             0
# 2   STU1002  Student_2   B.Com     2         84            93            21
# 3   STU1003  Student_3    B.Sc     4         43            18            92
# 4   STU1004  Student_4   B.Com     4         34            86            13
#
#    Attendance
# 0       93.32
# 1       59.56
# 2       48.01
# 3       69.36
# 4       84.80

# %%
df.tail()
# Out:
#      StudentID         Name Course  Year  MathScore  ScienceScore  \
# 1015   STU1650  Student_650     BA     2         65            71
# 1016   STU1907  Student_907  B.Com     3         64            85
# 1017   STU1660  Student_660     BA     4          0            96
# 1018   STU1231  Student_231   B.Sc     4         47            18
# 1019   STU1048   Student_48  B.Com     3         26            51
#
#       EnglishScore  Attendance
# 1015            63       89.70
# 1016            78       97.38
# 1017            18       65.34
# 1018            39       56.74
# 1019             8       44.23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   StudentID     1020 non-null   object
#  1   Name          1020 non-null   object
#  2   Course        1020 non-null   object
#  3   Year          1020 non-null   int64
#  4   MathScore     1020 non-null   int64
#  5   ScienceScore  1020 non-null   int64
#  6   EnglishScore  1020 non-null   int64
#  7   Attendance    990 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 63.9+ KB

# %%
#finding null values
df.isna().sum()
# Out:
# StudentID        0
# Name             0
# Course           0
# Year             0
# MathScore        0
# ScienceScore     0
# EnglishScore     0
# Attendance      30
# dtype: int64

# %%
#removing null values
df.dropna(axis = 1)
# Out:
#      StudentID         Name  Course  Year  MathScore  ScienceScore  \
# 0      STU1000    Student_0    B.Sc     4         26            67
# 1      STU1001    Student_1  B.Tech     3         93            63
# 2      STU1002    Student_2   B.Com     2         84            93
# 3      STU1003    Student_3    B.Sc     4         43            18
# 4      STU1004    Student_4   B.Com     4         34            86
# ...        ...          ...     ...   ...        ...           ...
# 1015   STU1650  Student_650      BA     2         65            71
# 1016   STU1907  Student_907   B.Com     3         64            85
# 1017   STU1660  Student_660      BA     4          0            96
# 1018   STU1231  Student_231    B.Sc     4         47            18
# 1019   STU1048   Student_48   B.Com     3         26            51
#
#       EnglishScore
# 0               48
# 1                0
# 2               21
# 3               92
# 4               13
# ...            ...
# ...

# %%
df
# Out:
#      StudentID         Name  Course  Year  MathScore  ScienceScore  \
# 0      STU1000    Student_0    B.Sc     4         26            67
# 1      STU1001    Student_1  B.Tech     3         93            63
# 2      STU1002    Student_2   B.Com     2         84            93
# 3      STU1003    Student_3    B.Sc     4         43            18
# 4      STU1004    Student_4   B.Com     4         34            86
# ...        ...          ...     ...   ...        ...           ...
# 1015   STU1650  Student_650      BA     2         65            71
# 1016   STU1907  Student_907   B.Com     3         64            85
# 1017   STU1660  Student_660      BA     4          0            96
# 1018   STU1231  Student_231    B.Sc     4         47            18
# 1019   STU1048   Student_48   B.Com     3         26            51
#
#       EnglishScore  Attendance
# 0               48       93.32
# 1                0       59.56
# 2               21       48.01
# 3               92       69.36
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   StudentID     1020 non-null   object
#  1   Name          1020 non-null   object
#  2   Course        1020 non-null   object
#  3   Year          1020 non-null   int64
#  4   MathScore     1020 non-null   int64
#  5   ScienceScore  1020 non-null   int64
#  6   EnglishScore  1020 non-null   int64
#  7   Attendance    990 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 63.9+ KB

# %%
df.describe()
# Out:
#               Year    MathScore  ScienceScore  EnglishScore  Attendance
# count  1020.000000  1020.000000   1020.000000   1020.000000  990.000000
# mean      2.497059    48.564706     49.269608     48.530392   70.205010
# std       1.104452    29.428290     28.702372     28.701948   17.831148
# min       1.000000     0.000000      0.000000      0.000000   40.090000
# 25%       2.000000    22.000000     24.000000     22.000000   54.622500
# 50%       3.000000    49.000000     50.000000     49.000000   69.475000
# 75%       3.000000    73.000000     73.000000     73.000000   86.365000
# max       4.000000    99.000000     99.000000     99.000000   99.900000

# %%
df.dropna(axis = 0)
# Out:
#      StudentID         Name  Course  Year  MathScore  ScienceScore  \
# 0      STU1000    Student_0    B.Sc     4         26            67
# 1      STU1001    Student_1  B.Tech     3         93            63
# 2      STU1002    Student_2   B.Com     2         84            93
# 3      STU1003    Student_3    B.Sc     4         43            18
# 4      STU1004    Student_4   B.Com     4         34            86
# ...        ...          ...     ...   ...        ...           ...
# 1015   STU1650  Student_650      BA     2         65            71
# 1016   STU1907  Student_907   B.Com     3         64            85
# 1017   STU1660  Student_660      BA     4          0            96
# 1018   STU1231  Student_231    B.Sc     4         47            18
# 1019   STU1048   Student_48   B.Com     3         26            51
#
#       EnglishScore  Attendance
# 0               48       93.32
# 1                0       59.56
# 2               21       48.01
# 3               92       69.36
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   StudentID     1020 non-null   object
#  1   Name          1020 non-null   object
#  2   Course        1020 non-null   object
#  3   Year          1020 non-null   int64
#  4   MathScore     1020 non-null   int64
#  5   ScienceScore  1020 non-null   int64
#  6   EnglishScore  1020 non-null   int64
#  7   Attendance    990 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 63.9+ KB

# %%
df["Course"].value_counts()
# Out:
# Course
# B.Sc      272
# B.Com     257
# BA        251
# B.Tech    240
# Name: count, dtype: int64

# %%
sb.countplot(df["Course"],label = "Countofcourses")
# Out:
# <Axes: xlabel='count', ylabel='Course'>

# %%
df.plot( subplots= True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df.plot.scatter(x = 'Course' , y = 'Year')
# Out:
# <Axes: xlabel='Course', ylabel='Year'>

# %%
plt.figure(figsize = (12,6))
plt.scatter(df['Course'],df['Attendance'],label = 'Cource',marker = 'o',color = 'blue')
plt.scatter(df['Year'],df['Attendance'],label = 'Attendence',marker = 's',color = 'green')


plt.legend()
plt.show()

# %%
df
# Out:
#      StudentID         Name  Course  Year  MathScore  ScienceScore  \
# 0      STU1000    Student_0    B.Sc     4         26            67
# 1      STU1001    Student_1  B.Tech     3         93            63
# 2      STU1002    Student_2   B.Com     2         84            93
# 3      STU1003    Student_3    B.Sc     4         43            18
# 4      STU1004    Student_4   B.Com     4         34            86
# ...        ...          ...     ...   ...        ...           ...
# 1015   STU1650  Student_650      BA     2         65            71
# 1016   STU1907  Student_907   B.Com     3         64            85
# 1017   STU1660  Student_660      BA     4          0            96
# 1018   STU1231  Student_231    B.Sc     4         47            18
# 1019   STU1048   Student_48   B.Com     3         26            51
#
#       EnglishScore  Attendance
# 0               48       93.32
# 1                0       59.56
# 2               21       48.01
# 3               92       69.36
# ...

# %% [markdown]
# #average scorce

# %%
np.average(df["MathScore"])
# Out:
# np.float64(48.56470588235294)

# %%
np.average(df["ScienceScore"])
# Out:
# np.float64(49.26960784313726)

# %%
np.average(df['EnglishScore'])
# Out:
# np.float64(48.530392156862746)

# %%
plt.figure(figsize = (12,6))
plt.scatter(df['MathScore'],df['Course'],label = 'MathScore',marker = 'o',color = 'blue')
plt.scatter(df['ScienceScore'],df['Course'],label = 'ScienceScore',marker = 's',color = 'green')
plt.scatter(df['EnglishScore'],df['Course'],label = 'EnglishScore',marker = 's',color = 'black')

plt.legend()
plt.show()

# %%
np.correlate(df["MathScore"], df["ScienceScore"])
# Out:
# array([2455838])

# %%
df
# Out:
#      StudentID         Name  Course  Year  MathScore  ScienceScore  \
# 0      STU1000    Student_0    B.Sc     4         26            67
# 1      STU1001    Student_1  B.Tech     3         93            63
# 2      STU1002    Student_2   B.Com     2         84            93
# 3      STU1003    Student_3    B.Sc     4         43            18
# 4      STU1004    Student_4   B.Com     4         34            86
# ...        ...          ...     ...   ...        ...           ...
# 1015   STU1650  Student_650      BA     2         65            71
# 1016   STU1907  Student_907   B.Com     3         64            85
# 1017   STU1660  Student_660      BA     4          0            96
# 1018   STU1231  Student_231    B.Sc     4         47            18
# 1019   STU1048   Student_48   B.Com     3         26            51
#
#       EnglishScore  Attendance
# 0               48       93.32
# 1                0       59.56
# 2               21       48.01
# 3               92       69.36
# ...

# %%
plt.boxplot(df['ScienceScore'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26c214581d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26c214597c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26c21458c50>],
#  'medians': [<matplotlib.lines.Line2D at 0x26c21459ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26c2145a1b0>],
#  'means': []}

# %%
plt.plot(df['Course'],df['Year'])
plt.legend()
plt.show()
# Out:
# C:\Users\pkuma\AppData\Local\Temp\ipykernel_23132\1185131106.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.bar(df['Year'],df['Course'],label = 'Admissions',color = 'blue')

plt.xlabel('Course')
plt.ylabel('Year')
plt.title('Admissions')
plt.legend()
plt.show()
